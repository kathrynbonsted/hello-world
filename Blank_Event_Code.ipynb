# %% [markdown]
# <a href="https://colab.research.google.com/github/kathrynbonsted/hello-world/blob/main/Blank_Event_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Import Scikit-learn California Housing Dataset

# %%
# Add in YearBuilt column
# Calculate the current year


# Create the 'YearBuilt' column by subtracting 'Age' from the current year



# Display the first few rows of the DataFrame to verify the new column

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Exploratory Data Analysis

# %%
# Exploratory Data Analysis

# %%
# Exploratory Data Analysis

# %% [markdown]
# # Vizualization

# %%
# Import MatPlotLib and Visualize the data

# %%
# Import Seaborn to show different visuals

# Line chart


# Pie chart

# %%
# Scatter plot to show Map

# %%
# Map 2

# %% [markdown]
# # Identify Correlations for Linear Regression

# %%
# Correlation table

# %%
# Visualize Correlations

# %% [markdown]
# # Single Linear Regression Model

# %%
# Import libraries and modules needed

# Select single feature and target

# Split into training and test sets

# Train the model

# Predictions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Model Evaluation


print(f"R-Squared: ")
print(f"Mean Squared Error: ")
print(f"Root Mean Squared Error: ")
print(f"Mean Absolute Error: ")
# Out:
# R-Squared:
# Mean Squared Error:
# Root Mean Squared Error:
# Mean Absolute Error:

# %%
# Visualize Model

# %% [markdown]
# # Multiple Linear Regression Model

# %%
# Select all features except target

# Split into training and test sets

# Train the model

# Predictions

# %%
# Model Evaluation

print(f"R-Squared: ")
print(f"Mean Squared Error: ")
print(f"Root Mean Squared Error: ")
print(f"Mean Absolute Error: ")
# Out:
# R-Squared:
# Mean Squared Error:
# Root Mean Squared Error:
# Mean Absolute Error:

# %%
# Visualize Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
